# %%
import os
import re
import results
import numpy as np
import pandas as pd
import os.path as op
from sklearn.metrics import average_precision_score

# %%
fns = list(filter(lambda x: ".csv" in x, [a for a in os.walk("../models")][0][2]))

# %%
is_ABC = lambda x: "ABC" in x
is_NL = lambda x: "NL" in x
is_CN = lambda x: "CN" in x
is_SDI = lambda x: "SDI" in x
is_SDO = lambda x: "_SDO" in x
is_01 = lambda x: "_0.1_" in x
is_1 = lambda x: "_1_" in x
is_10 = lambda x: "_10_" in x
is_test = lambda x: "test" in x
is_train = lambda x: "train" in x
is_n = lambda x,n: "_"+str(n)+"_" in x
is_MNIST = lambda x: re.search("^MNIST", x)
is_FMNIST = lambda x: re.search("FMNIST", x)
is_KMNIST = lambda x: re.search("KMNIST", x)
is_CIFAR = lambda x: re.search("CIFAR", x)
is_HAM = lambda x: re.search("HAM", x)
is_PENG = lambda x: re.search("PENG", x)

# %%
fns = list(filter(is_test, fns))

# %%
total = {
    0.1: {
        "CIFAR": {
            "Palma": None,
            "Gini": None,
            "Plain": None,
            "A": None,
            "Npp": None,
            "Nre": None,
            "ABC": None,
            "NL": None,
        },
        "MNIST": {
            "Palma": None,
            "Gini": None,
            "Plain": None,
            "A": None,
            "Npp": None,
            "Nre": None,
            "ABC": None,
            "NL": None,
        },
        "FMNIST": {
            "Palma": None,
            "Gini": None,
            "Plain": None,
            "A": None,
            "Npp": None,
            "Nre": None,
            "ABC": None,
            "NL": None,
        },
        "KMNIST": {
            "Palma": None,
            "Gini": None,
            "Plain": None,
            "A": None,
            "Npp": None,
            "Nre": None,
            "ABC": None,
            "NL": None,
        }
    },
    1: {
        "CIFAR": {
            "Palma": None,
            "Gini": None,
            "Plain": None,
            "A": None,
            "Npp": None,
            "Nre": None,
            "ABC": None,
            "NL": None,
        },
        "MNIST": {
            "Palma": None,
            "Gini": None,
            "Plain": None,
            "A": None,
            "Npp": None,
            "Nre": None,
            "ABC": None,
            "NL": None,
        },
        "FMNIST": {
            "Palma": None,
            "Gini": None,
            "Plain": None,
            "A": None,
            "Npp": None,
            "Nre": None,
            "ABC": None,
            "NL": None,
        },
        "KMNIST": {
            "Palma": None,
            "Gini": None,
            "Plain": None,
            "A": None,
            "Npp": None,
            "Nre": None,
            "ABC": None,
            "NL": None,
        }    
    },
    10: {
        "CIFAR": {
            "Palma": None,
            "Gini": None,
            "Plain": None,
            "A": None,
            "Npp": None,
            "Nre": None,
            "ABC": None,
            "NL": None,
        },
        "MNIST": {
            "Palma": None,
            "Gini": None,
            "Plain": None,
            "A": None,
            "Npp": None,
            "Nre": None,
            "ABC": None,
            "NL": None,
        },
        "FMNIST": {
            "Palma": None,
            "Gini": None,
            "Plain": None,
            "A": None,
            "Npp": None,
            "Nre": None,
            "ABC": None,
            "NL": None,
        },
        "KMNIST": {
            "Palma": None,
            "Gini": None,
            "Plain": None,
            "A": None,
            "Npp": None,
            "Nre": None,
            "ABC": None,
            "NL": None,
        }
    }
}

# %% [markdown]
# # 0.1

# %%
CN = [op.join("../models", a) for a in 
     list(filter(lambda x: is_CN(x) and is_CIFAR(x) and is_01(x) and is_SDI(x), fns))]
ABC = [op.join("../models", a) for a in 
     list(filter(lambda x: is_ABC(x) and is_CIFAR(x) and is_01(x) and is_SDI(x), fns))]
NL = [op.join("../models", a) for a in 
     list(filter(lambda x: is_NL(x) and is_CIFAR(x) and is_01(x) and is_SDI(x), fns))]
CN_plain = [results.read_CN(a, "plain", average_precision_score) for a in CN]
CN_gini = [results.read_CN(a, "gini", average_precision_score) for a in CN]
CN_palma = [results.read_CN(a, "palma", average_precision_score) for a in CN]
CN_a = [results.read_CN(a, "anomaly_score", average_precision_score) for a in CN]
CN_npp = [results.read_CN(a, "n_pp", average_precision_score) for a in CN]
CN_nre = [results.read_CN(a, "n_re", average_precision_score) for a in CN]
ABC_ = [results.read_ABCNL(a, average_precision_score) for a in ABC]
NL_ = [results.read_ABCNL(a, average_precision_score) for a in NL]
column = [
    str(np.mean(a).round(4))+" ± "+str(np.std(a).round(4)) for a in [
        CN_palma, CN_gini, CN_plain, CN_a, CN_npp, CN_nre, ABC_, NL_
    ]
]
total[0.1]["CIFAR"]["Palma"] = column[0]
total[0.1]["CIFAR"]["Gini"] = column[1]
total[0.1]["CIFAR"]["Plain"] = column[2]
total[0.1]["CIFAR"]["A"] = column[3]
total[0.1]["CIFAR"]["Npp"] = column[4]
total[0.1]["CIFAR"]["Nre"] = column[5]
total[0.1]["CIFAR"]["ABC"] = column[6]
total[0.1]["CIFAR"]["NL"] = column[7]
print(len(CN), len(ABC), len(NL))
print(column)
# Out:
# 9 10 10
# ['0.2626 ± 0.075', '0.2631 ± 0.0753', '0.1 ± 0.0', '0.1055 ± 0.0385', '0.2608 ± 0.0741', '0.1082 ± 0.0429', '0.1237 ± 0.0641', '0.1076 ± 0.0308']

# %%
CN = [op.join("../models", a) for a in 
     list(filter(lambda x: is_CN(x) and is_MNIST(x) and is_01(x) and is_SDI(x), fns))]
ABC = [op.join("../models", a) for a in 
     list(filter(lambda x: is_ABC(x) and is_MNIST(x) and is_01(x) and is_SDI(x), fns))]
NL = [op.join("../models", a) for a in 
     list(filter(lambda x: is_NL(x) and is_MNIST(x) and is_01(x) and is_SDI(x), fns))]
CN_plain = [results.read_CN(a, "plain", average_precision_score) for a in CN]
CN_gini = [results.read_CN(a, "gini", average_precision_score) for a in CN]
CN_palma = [results.read_CN(a, "palma", average_precision_score) for a in CN]
CN_a = [results.read_CN(a, "anomaly_score", average_precision_score) for a in CN]
CN_npp = [results.read_CN(a, "n_pp", average_precision_score) for a in CN]
CN_nre = [results.read_CN(a, "n_re", average_precision_score) for a in CN]
ABC_ = [results.read_ABCNL(a, average_precision_score) for a in ABC]
NL_ = [results.read_ABCNL(a, average_precision_score) for a in NL]
column = [
    str(np.mean(a).round(4))+" ± "+str(np.std(a).round(4)) for a in [
        CN_palma, CN_gini, CN_plain, CN_a, CN_npp, CN_nre, ABC_, NL_
    ]
]
total[0.1]["MNIST"]["Palma"] = column[0]
total[0.1]["MNIST"]["Gini"] = column[1]
total[0.1]["MNIST"]["Plain"] = column[2]
total[0.1]["MNIST"]["A"] = column[3]
total[0.1]["MNIST"]["Npp"] = column[4]
total[0.1]["MNIST"]["Nre"] = column[5]
total[0.1]["MNIST"]["ABC"] = column[6]
total[0.1]["MNIST"]["NL"] = column[7]
print(len(CN), len(ABC), len(NL))
print(column)
# Out:
# 10 10 10
# ['0.9678 ± 0.0163', '0.9677 ± 0.0164', '0.6468 ± 0.1244', '0.8299 ± 0.0774', '0.9121 ± 0.0699', '0.8577 ± 0.0611', '0.1434 ± 0.1153', '0.1214 ± 0.0737']

# %%
CN = [op.join("../models", a) for a in 
     list(filter(lambda x: is_CN(x) and is_KMNIST(x) and is_01(x) and is_SDI(x), fns))]
ABC = [op.join("../models", a) for a in 
     list(filter(lambda x: is_ABC(x) and is_KMNIST(x) and is_01(x) and is_SDI(x), fns))]
NL = [op.join("../models", a) for a in 
     list(filter(lambda x: is_NL(x) and is_KMNIST(x) and is_01(x) and is_SDI(x), fns))]
CN_plain = [results.read_CN(a, "plain", average_precision_score) for a in CN]
CN_gini = [results.read_CN(a, "gini", average_precision_score) for a in CN]
CN_palma = [results.read_CN(a, "palma", average_precision_score) for a in CN]
CN_a = [results.read_CN(a, "anomaly_score", average_precision_score) for a in CN]
CN_npp = [results.read_CN(a, "n_pp", average_precision_score) for a in CN]
CN_nre = [results.read_CN(a, "n_re", average_precision_score) for a in CN]
ABC_ = [results.read_ABCNL(a, average_precision_score) for a in ABC]
NL_ = [results.read_ABCNL(a, average_precision_score) for a in NL]
column = [
    str(np.mean(a).round(4))+" ± "+str(np.std(a).round(4)) for a in [
        CN_palma, CN_gini, CN_plain, CN_a, CN_npp, CN_nre, ABC_, NL_
    ]
]
total[0.1]["KMNIST"]["Palma"] = column[0]
total[0.1]["KMNIST"]["Gini"] = column[1]
total[0.1]["KMNIST"]["Plain"] = column[2]
total[0.1]["KMNIST"]["A"] = column[3]
total[0.1]["KMNIST"]["Npp"] = column[4]
total[0.1]["KMNIST"]["Nre"] = column[5]
total[0.1]["KMNIST"]["ABC"] = column[6]
total[0.1]["KMNIST"]["NL"] = column[7]
print(len(CN), len(ABC), len(NL))
print(column)
# Out:
# 10 10 10
# ['0.7909 ± 0.0559', '0.7912 ± 0.056', '0.2852 ± 0.0549', '0.3974 ± 0.1148', '0.8206 ± 0.0431', '0.4746 ± 0.091', '0.1128 ± 0.0503', '0.1101 ± 0.0419']

# %%
CN = [op.join("../models", a) for a in 
     list(filter(lambda x: is_CN(x) and is_FMNIST(x) and is_01(x) and is_SDI(x), fns))]
ABC = [op.join("../models", a) for a in 
     list(filter(lambda x: is_ABC(x) and is_FMNIST(x) and is_01(x) and is_SDI(x), fns))]
NL = [op.join("../models", a) for a in 
     list(filter(lambda x: is_NL(x) and is_FMNIST(x) and is_01(x) and is_SDI(x), fns))]
CN_plain = [results.read_CN(a, "plain", average_precision_score) for a in CN]
CN_gini = [results.read_CN(a, "gini", average_precision_score) for a in CN]
CN_palma = [results.read_CN(a, "palma", average_precision_score) for a in CN]
CN_a = [results.read_CN(a, "anomaly_score", average_precision_score) for a in CN]
CN_npp = [results.read_CN(a, "n_pp", average_precision_score) for a in CN]
CN_nre = [results.read_CN(a, "n_re", average_precision_score) for a in CN]
ABC_ = [results.read_ABCNL(a, average_precision_score) for a in ABC]
NL_ = [results.read_ABCNL(a, average_precision_score) for a in NL]
column = [
    str(np.mean(a).round(4))+" ± "+str(np.std(a).round(4)) for a in [
        CN_palma, CN_gini, CN_plain, CN_a, CN_npp, CN_nre, ABC_, NL_
    ]
]
total[0.1]["FMNIST"]["Palma"] = column[0]
total[0.1]["FMNIST"]["Gini"] = column[1]
total[0.1]["FMNIST"]["Plain"] = column[2]
total[0.1]["FMNIST"]["A"] = column[3]
total[0.1]["FMNIST"]["Npp"] = column[4]
total[0.1]["FMNIST"]["Nre"] = column[5]
total[0.1]["FMNIST"]["ABC"] = column[6]
total[0.1]["FMNIST"]["NL"] = column[7]
print(len(CN), len(ABC), len(NL))
print(column)
# Out:
# 10 10 10
# ['0.7999 ± 0.1351', '0.8008 ± 0.137', '0.3726 ± 0.2409', '0.387 ± 0.281', '0.7423 ± 0.1469', '0.394 ± 0.2972', '0.1421 ± 0.0786', '0.1269 ± 0.0634']

# %% [markdown]
# # 1

# %%
selfun = lambda x: is_CIFAR(x) and is_1(x) and is_SDI(x) and not is_10(x) and not is_01(x)
CN = [op.join("../models", a) for a in 
     list(
         filter(lambda x: is_CN(x) and selfun(x), fns)
     )]
ABC = [op.join("../models", a) for a in 
     list(filter(lambda x: is_ABC(x) and selfun(x), fns))]
NL = [op.join("../models", a) for a in 
     list(filter(lambda x: is_NL(x) and selfun(x), fns))]
CN_plain = [results.read_CN(a, "plain", average_precision_score) for a in CN]
CN_gini = [results.read_CN(a, "gini", average_precision_score) for a in CN]
CN_palma = [results.read_CN(a, "palma", average_precision_score) for a in CN]
CN_a = [results.read_CN(a, "anomaly_score", average_precision_score) for a in CN]
CN_npp = [results.read_CN(a, "n_pp", average_precision_score) for a in CN]
CN_nre = [results.read_CN(a, "n_re", average_precision_score) for a in CN]
ABC_ = [results.read_ABCNL(a, average_precision_score) for a in ABC]
NL_ = [results.read_ABCNL(a, average_precision_score) for a in NL]
column = [
    str(np.mean(a).round(4))+" ± "+str(np.std(a).round(4)) for a in [
        CN_palma, CN_gini, CN_plain, CN_a, CN_npp, CN_nre, ABC_, NL_
    ]
]
total[1]["CIFAR"]["Palma"] = column[0]
total[1]["CIFAR"]["Gini"] = column[1]
total[1]["CIFAR"]["Plain"] = column[2]
total[1]["CIFAR"]["A"] = column[3]
total[1]["CIFAR"]["Npp"] = column[4]
total[1]["CIFAR"]["Nre"] = column[5]
total[1]["CIFAR"]["ABC"] = column[6]
total[1]["CIFAR"]["NL"] = column[7]
print(len(CN), len(ABC), len(NL))
print(column)
# Out:
# 10 10 10
# ['0.4201 ± 0.1159', '0.4224 ± 0.1151', '0.1227 ± 0.0274', '0.1368 ± 0.0658', '0.4419 ± 0.1131', '0.1373 ± 0.066', '0.1298 ± 0.0744', '0.1078 ± 0.0313']

# %%
selfun = lambda x: is_MNIST(x) and is_1(x) and is_SDI(x) and not is_10(x) and not is_01(x)
CN = [op.join("../models", a) for a in 
     list(filter(lambda x: is_CN(x) and selfun(x), fns))]
ABC = [op.join("../models", a) for a in 
     list(filter(lambda x: is_ABC(x) and selfun(x), fns))]
NL = [op.join("../models", a) for a in 
     list(filter(lambda x: is_NL(x) and selfun(x), fns))]
CN_plain = [results.read_CN(a, "plain", average_precision_score) for a in CN]
CN_gini = [results.read_CN(a, "gini", average_precision_score) for a in CN]
CN_palma = [results.read_CN(a, "palma", average_precision_score) for a in CN]
CN_a = [results.read_CN(a, "anomaly_score", average_precision_score) for a in CN]
CN_npp = [results.read_CN(a, "n_pp", average_precision_score) for a in CN]
CN_nre = [results.read_CN(a, "n_re", average_precision_score) for a in CN]
ABC_ = [results.read_ABCNL(a, average_precision_score) for a in ABC]
NL_ = [results.read_ABCNL(a, average_precision_score) for a in NL]
column = [
    str(np.mean(a).round(4))+" ± "+str(np.std(a).round(4)) for a in [
        CN_palma, CN_gini, CN_plain, CN_a, CN_npp, CN_nre, ABC_, NL_
    ]
]
total[1]["MNIST"]["Palma"] = column[0]
total[1]["MNIST"]["Gini"] = column[1]
total[1]["MNIST"]["Plain"] = column[2]
total[1]["MNIST"]["A"] = column[3]
total[1]["MNIST"]["Npp"] = column[4]
total[1]["MNIST"]["Nre"] = column[5]
total[1]["MNIST"]["ABC"] = column[6]
total[1]["MNIST"]["NL"] = column[7]
print(len(CN), len(ABC), len(NL))
print(column)
# Out:
# 10 10 10
# ['0.9854 ± 0.02', '0.9944 ± 0.0028', '0.933 ± 0.0246', '0.9675 ± 0.0176', '0.4527 ± 0.1078', '0.973 ± 0.0134', '0.1441 ± 0.1197', '0.1196 ± 0.0699']

# %%
selfun = lambda x: is_KMNIST(x) and is_1(x) and is_SDI(x) and not is_10(x) and not is_01(x)
CN = [op.join("../models", a) for a in 
     list(filter(lambda x: is_CN(x) and selfun(x), fns))]
ABC = [op.join("../models", a) for a in 
     list(filter(lambda x: is_ABC(x) and selfun(x), fns))]
NL = [op.join("../models", a) for a in 
     list(filter(lambda x: is_NL(x) and selfun(x), fns))]
CN_plain = [results.read_CN(a, "plain", average_precision_score) for a in CN]
CN_gini = [results.read_CN(a, "gini", average_precision_score) for a in CN]
CN_palma = [results.read_CN(a, "palma", average_precision_score) for a in CN]
CN_a = [results.read_CN(a, "anomaly_score", average_precision_score) for a in CN]
CN_npp = [results.read_CN(a, "n_pp", average_precision_score) for a in CN]
CN_nre = [results.read_CN(a, "n_re", average_precision_score) for a in CN]
ABC_ = [results.read_ABCNL(a, average_precision_score) for a in ABC]
NL_ = [results.read_ABCNL(a, average_precision_score) for a in NL]
column = [
    str(np.mean(a).round(4))+" ± "+str(np.std(a).round(4)) for a in [
        CN_palma, CN_gini, CN_plain, CN_a, CN_npp, CN_nre, ABC_, NL_
    ]
]
total[1]["KMNIST"]["Palma"] = column[0]
total[1]["KMNIST"]["Gini"] = column[1]
total[1]["KMNIST"]["Plain"] = column[2]
total[1]["KMNIST"]["A"] = column[3]
total[1]["KMNIST"]["Npp"] = column[4]
total[1]["KMNIST"]["Nre"] = column[5]
total[1]["KMNIST"]["ABC"] = column[6]
total[1]["KMNIST"]["NL"] = column[7]
print(len(CN), len(ABC), len(NL))
print(column)
# Out:
# 10 10 10
# ['0.9425 ± 0.0205', '0.9427 ± 0.0203', '0.692 ± 0.0512', '0.6855 ± 0.1169', '0.7059 ± 0.0544', '0.7975 ± 0.047', '0.1128 ± 0.0503', '0.1105 ± 0.0428']

# %%
selfun = lambda x: is_FMNIST(x) and is_1(x) and is_SDI(x) and not is_10(x) and not is_01(x)
CN = [op.join("../models", a) for a in 
     list(filter(lambda x: is_CN(x) and selfun(x), fns))]
ABC = [op.join("../models", a) for a in 
     list(filter(lambda x: is_ABC(x) and selfun(x), fns))]
NL = [op.join("../models", a) for a in 
     list(filter(lambda x: is_NL(x) and selfun(x), fns))]
CN_plain = [results.read_CN(a, "plain", average_precision_score) for a in CN]
CN_gini = [results.read_CN(a, "gini", average_precision_score) for a in CN]
CN_palma = [results.read_CN(a, "palma", average_precision_score) for a in CN]
CN_a = [results.read_CN(a, "anomaly_score", average_precision_score) for a in CN]
CN_npp = [results.read_CN(a, "n_pp", average_precision_score) for a in CN]
CN_nre = [results.read_CN(a, "n_re", average_precision_score) for a in CN]
ABC_ = [results.read_ABCNL(a, average_precision_score) for a in ABC]
NL_ = [results.read_ABCNL(a, average_precision_score) for a in NL]
column = [
    str(np.mean(a).round(4))+" ± "+str(np.std(a).round(4)) for a in [
        CN_palma, CN_gini, CN_plain, CN_a, CN_npp, CN_nre, ABC_, NL_
    ]
]
total[1]["FMNIST"]["Palma"] = column[0]
total[1]["FMNIST"]["Gini"] = column[1]
total[1]["FMNIST"]["Plain"] = column[2]
total[1]["FMNIST"]["A"] = column[3]
total[1]["FMNIST"]["Npp"] = column[4]
total[1]["FMNIST"]["Nre"] = column[5]
total[1]["FMNIST"]["ABC"] = column[6]
total[1]["FMNIST"]["NL"] = column[7]
print(len(CN), len(ABC), len(NL))
print(column)
# Out:
# 10 10 10
# ['0.8763 ± 0.0916', '0.8898 ± 0.1006', '0.6483 ± 0.2308', '0.4849 ± 0.2694', '0.5839 ± 0.191', '0.495 ± 0.2928', '0.1392 ± 0.0752', '0.1268 ± 0.0632']

# %% [markdown]
# # 10

# %%
CN = [op.join("../models", a) for a in 
     list(filter(lambda x: is_CN(x) and is_CIFAR(x) and is_10(x) and is_SDI(x), fns))]
ABC = [op.join("../models", a) for a in 
     list(filter(lambda x: is_ABC(x) and is_CIFAR(x) and is_10(x) and is_SDI(x), fns))]
NL = [op.join("../models", a) for a in 
     list(filter(lambda x: is_NL(x) and is_CIFAR(x) and is_10(x) and is_SDI(x), fns))]
CN_plain = [results.read_CN(a, "plain", average_precision_score) for a in CN]
CN_gini = [results.read_CN(a, "gini", average_precision_score) for a in CN]
CN_palma = [results.read_CN(a, "palma", average_precision_score) for a in CN]
CN_a = [results.read_CN(a, "anomaly_score", average_precision_score) for a in CN]
CN_npp = [results.read_CN(a, "n_pp", average_precision_score) for a in CN]
CN_nre = [results.read_CN(a, "n_re", average_precision_score) for a in CN]
ABC_ = [results.read_ABCNL(a, average_precision_score) for a in ABC]
NL_ = [results.read_ABCNL(a, average_precision_score) for a in NL]
column = [
    str(np.mean(a).round(4))+" ± "+str(np.std(a).round(4)) for a in [
        CN_palma, CN_gini, CN_plain, CN_a, CN_npp, CN_nre, ABC_, NL_
    ]
]
total[10]["CIFAR"]["Palma"] = column[0]
total[10]["CIFAR"]["Gini"] = column[1]
total[10]["CIFAR"]["Plain"] = column[2]
total[10]["CIFAR"]["A"] = column[3]
total[10]["CIFAR"]["Npp"] = column[4]
total[10]["CIFAR"]["Nre"] = column[5]
total[10]["CIFAR"]["ABC"] = column[6]
total[10]["CIFAR"]["NL"] = column[7]
print(len(CN), len(ABC), len(NL))
print(column)
# Out:
# 10 10 10
# ['0.6534 ± 0.133', '0.6615 ± 0.1325', '0.4024 ± 0.1258', '0.2424 ± 0.1311', '0.408 ± 0.0582', '0.2464 ± 0.1273', '0.1183 ± 0.0575', '0.1077 ± 0.0309']

# %%
CN = [op.join("../models", a) for a in 
     list(filter(lambda x: is_CN(x) and is_MNIST(x) and is_10(x) and is_SDI(x), fns))]
ABC = [op.join("../models", a) for a in 
     list(filter(lambda x: is_ABC(x) and is_MNIST(x) and is_10(x) and is_SDI(x), fns))]
NL = [op.join("../models", a) for a in 
     list(filter(lambda x: is_NL(x) and is_MNIST(x) and is_10(x) and is_SDI(x), fns))]
CN_plain = [results.read_CN(a, "plain", average_precision_score) for a in CN]
CN_gini = [results.read_CN(a, "gini", average_precision_score) for a in CN]
CN_palma = [results.read_CN(a, "palma", average_precision_score) for a in CN]
CN_a = [results.read_CN(a, "anomaly_score", average_precision_score) for a in CN]
CN_npp = [results.read_CN(a, "n_pp", average_precision_score) for a in CN]
CN_nre = [results.read_CN(a, "n_re", average_precision_score) for a in CN]
ABC_ = [results.read_ABCNL(a, average_precision_score) for a in ABC]
NL_ = [results.read_ABCNL(a, average_precision_score) for a in NL]
column = [
    str(np.mean(a).round(4))+" ± "+str(np.std(a).round(4)) for a in [
        CN_palma, CN_gini, CN_plain, CN_a, CN_npp, CN_nre, ABC_, NL_
    ]
]
total[10]["MNIST"]["Palma"] = column[0]
total[10]["MNIST"]["Gini"] = column[1]
total[10]["MNIST"]["Plain"] = column[2]
total[10]["MNIST"]["A"] = column[3]
total[10]["MNIST"]["Npp"] = column[4]
total[10]["MNIST"]["Nre"] = column[5]
total[10]["MNIST"]["ABC"] = column[6]
total[10]["MNIST"]["NL"] = column[7]
print(len(CN), len(ABC), len(NL))
print(column)
# Out:
# 10 10 10
# ['0.923 ± 0.0599', '0.9986 ± 0.001', '0.9809 ± 0.0066', '0.9358 ± 0.1257', '0.116 ± 0.0225', '0.9647 ± 0.0555', '0.1524 ± 0.1254', '0.1223 ± 0.0747']

# %%
CN = [op.join("../models", a) for a in 
     list(filter(lambda x: is_CN(x) and is_KMNIST(x) and is_10(x) and is_SDI(x), fns))]
ABC = [op.join("../models", a) for a in 
     list(filter(lambda x: is_ABC(x) and is_KMNIST(x) and is_10(x) and is_SDI(x), fns))]
NL = [op.join("../models", a) for a in 
     list(filter(lambda x: is_NL(x) and is_KMNIST(x) and is_10(x) and is_SDI(x), fns))]
CN_plain = [results.read_CN(a, "plain", average_precision_score) for a in CN]
CN_gini = [results.read_CN(a, "gini", average_precision_score) for a in CN]
CN_palma = [results.read_CN(a, "palma", average_precision_score) for a in CN]
CN_a = [results.read_CN(a, "anomaly_score", average_precision_score) for a in CN]
CN_npp = [results.read_CN(a, "n_pp", average_precision_score) for a in CN]
CN_nre = [results.read_CN(a, "n_re", average_precision_score) for a in CN]
ABC_ = [results.read_ABCNL(a, average_precision_score) for a in ABC]
NL_ = [results.read_ABCNL(a, average_precision_score) for a in NL]
column = [
    str(np.mean(a).round(4))+" ± "+str(np.std(a).round(4)) for a in [
        CN_palma, CN_gini, CN_plain, CN_a, CN_npp, CN_nre, ABC_, NL_
    ]
]
total[10]["KMNIST"]["Palma"] = column[0]
total[10]["KMNIST"]["Gini"] = column[1]
total[10]["KMNIST"]["Plain"] = column[2]
total[10]["KMNIST"]["A"] = column[3]
total[10]["KMNIST"]["Npp"] = column[4]
total[10]["KMNIST"]["Nre"] = column[5]
total[10]["KMNIST"]["ABC"] = column[6]
total[10]["KMNIST"]["NL"] = column[7]
print(len(CN), len(ABC), len(NL))
print(column)
# Out:
# 10 10 10
# ['0.9763 ± 0.0116', '0.98 ± 0.0128', '0.9023 ± 0.0284', '0.7676 ± 0.1253', '0.2549 ± 0.0583', '0.912 ± 0.0395', '0.1128 ± 0.0503', '0.1102 ± 0.0422']

# %%
CN = [op.join("../models", a) for a in 
     list(filter(lambda x: is_CN(x) and is_FMNIST(x) and is_10(x) and is_SDI(x), fns))]
ABC = [op.join("../models", a) for a in 
     list(filter(lambda x: is_ABC(x) and is_FMNIST(x) and is_10(x) and is_SDI(x), fns))]
NL = [op.join("../models", a) for a in 
     list(filter(lambda x: is_NL(x) and is_FMNIST(x) and is_10(x) and is_SDI(x), fns))]
CN_plain = [results.read_CN(a, "plain", average_precision_score) for a in CN]
CN_gini = [results.read_CN(a, "gini", average_precision_score) for a in CN]
CN_palma = [results.read_CN(a, "palma", average_precision_score) for a in CN]
CN_a = [results.read_CN(a, "anomaly_score", average_precision_score) for a in CN]
CN_npp = [results.read_CN(a, "n_pp", average_precision_score) for a in CN]
CN_nre = [results.read_CN(a, "n_re", average_precision_score) for a in CN]
ABC_ = [results.read_ABCNL(a, average_precision_score) for a in ABC]
NL_ = [results.read_ABCNL(a, average_precision_score) for a in NL]
column = [
    str(np.mean(a).round(4))+" ± "+str(np.std(a).round(4)) for a in [
        CN_palma, CN_gini, CN_plain, CN_a, CN_npp, CN_nre, ABC_, NL_
    ]
]
total[10]["FMNIST"]["Palma"] = column[0]
total[10]["FMNIST"]["Gini"] = column[1]
total[10]["FMNIST"]["Plain"] = column[2]
total[10]["FMNIST"]["A"] = column[3]
total[10]["FMNIST"]["Npp"] = column[4]
total[10]["FMNIST"]["Nre"] = column[5]
total[10]["FMNIST"]["ABC"] = column[6]
total[10]["FMNIST"]["NL"] = column[7]
print(len(CN), len(ABC), len(NL))
print(column)
# Out:
# 10 10 10
# ['0.851 ± 0.1007', '0.9421 ± 0.0702', '0.8347 ± 0.1378', '0.485 ± 0.2583', '0.2688 ± 0.13', '0.5183 ± 0.2766', '0.1471 ± 0.079', '0.1267 ± 0.0632']

# %% [markdown]
# # Results

# %%
first = pd.DataFrame(total[0.1])
first["Proportion"] = 0.1
second = pd.DataFrame(total[1])
second["Proportion"] = 1
third = pd.DataFrame(total[10])
third["Proportion"] = 10

# %%
total_df = pd.concat([first, second, third])

# %%
total_df
# Out:
#                  CIFAR            MNIST           FMNIST           KMNIST  \
# Palma   0.2626 ± 0.075  0.9678 ± 0.0163  0.7999 ± 0.1351  0.7909 ± 0.0559
# Gini   0.2631 ± 0.0753  0.9677 ± 0.0164   0.8008 ± 0.137   0.7912 ± 0.056
# Plain        0.1 ± 0.0  0.6468 ± 0.1244  0.3726 ± 0.2409  0.2852 ± 0.0549
# A      0.1055 ± 0.0385  0.8299 ± 0.0774    0.387 ± 0.281  0.3974 ± 0.1148
# Npp    0.2608 ± 0.0741  0.9121 ± 0.0699  0.7423 ± 0.1469  0.8206 ± 0.0431
# Nre    0.1082 ± 0.0429  0.8577 ± 0.0611   0.394 ± 0.2972   0.4746 ± 0.091
# ABC    0.1237 ± 0.0641  0.1434 ± 0.1153  0.1421 ± 0.0786  0.1128 ± 0.0503
# NL     0.1076 ± 0.0308  0.1214 ± 0.0737  0.1269 ± 0.0634  0.1101 ± 0.0419
# Palma  0.4201 ± 0.1159    0.9854 ± 0.02  0.8763 ± 0.0916  0.9425 ± 0.0205
# Gini   0.4224 ± 0.1151  0.9944 ± 0.0028  0.8898 ± 0.1006  0.9427 ± 0.0203
# Plain  0.1227 ± 0.0274   0.933 ± 0.0246  0.6483 ± 0.2308   0.692 ± 0.0512
# A      0.1368 ± 0.0658  0.9675 ± 0.0176  0.4849 ± 0.2694  0.6855 ± 0.1169
# Npp    0.4419 ± 0.1131  0.4527 ± 0.1078   0.5839 ± 0.191  0.7059 ± 0.0544
# Nre     0.1373 ± 0.066   0.973 ± 0.0134   0.495 ± 0.2928   0.7975 ± 0.047
# ABC    0.1298 ± 0.0744  0.1441 ± 0.1197  0.1392 ± 0.0752  0.1128 ± 0.0503
# NL     0.1078 ± 0.0313  0.1196 ± 0.0699  0.1268 ± 0.0632  0.1105 ± 0.0428
# Palma   0.6534 ± 0.133   0.923 ± 0.0599   0.851 ± 0.1007  0.9763 ± 0.0116
# Gini   0.6615 ± 0.1325   0.9986 ± 0.001  0.9421 ± 0.0702    0.98 ± 0.0128
# Plain  0.4024 ± 0.1258  0.9809 ± 0.0066  0.8347 ± 0.1378  0.9023 ± 0.0284
# A      0.2424 ± 0.1311  0.9358 ± 0.1257   0.485 ± 0.2583  0.7676 ± 0.1253
# Npp     0.408 ± 0.0582   0.116 ± 0.0225    0.2688 ± 0.13  0.2549 ± 0.0583
# Nre    0.2464 ± 0.1273  0.9647 ± 0.0555  0.5183 ± 0.2766   0.912 ± 0.0395
# ABC    0.1183 ± 0.0575  0.1524 ± 0.1254   0.1471 ± 0.079  0.1128 ± 0.0503
# NL     0.1077 ± 0.0309  0.1223 ± 0.0747  0.1267 ± 0.0632  0.1102 ± 0.0422
#
#        Proportion
# Palma         0.1
# Gini          0.1
# Plain         0.1
# A             0.1
# Npp           0.1
# Nre           0.1
# ABC           0.1
# NL            0.1
# Palma         1.0
# Gini          1.0
# Plain         1.0
# A             1.0
# Npp           1.0
# Nre           1.0
# ABC           1.0
# NL            1.0
# Palma        10.0
# Gini         10.0
# Plain        10.0
# A            10.0
# Npp          10.0
# Nre          10.0
# ABC          10.0
# NL           10.0

# %%
print(total_df.to_latex())
# Out:
# \begin{tabular}{lllllr}
# \toprule
# {} &            CIFAR &            MNIST &           FMNIST &           KMNIST &  Proportion \\
# \midrule
# Palma &   0.2626 ± 0.075 &  0.9678 ± 0.0163 &  0.7999 ± 0.1351 &  0.7909 ± 0.0559 &         0.1 \\
# Gini  &  0.2631 ± 0.0753 &  0.9677 ± 0.0164 &   0.8008 ± 0.137 &   0.7912 ± 0.056 &         0.1 \\
# Plain &        0.1 ± 0.0 &  0.6468 ± 0.1244 &  0.3726 ± 0.2409 &  0.2852 ± 0.0549 &         0.1 \\
# A     &  0.1055 ± 0.0385 &  0.8299 ± 0.0774 &    0.387 ± 0.281 &  0.3974 ± 0.1148 &         0.1 \\
# Npp   &  0.2608 ± 0.0741 &  0.9121 ± 0.0699 &  0.7423 ± 0.1469 &  0.8206 ± 0.0431 &         0.1 \\
# Nre   &  0.1082 ± 0.0429 &  0.8577 ± 0.0611 &   0.394 ± 0.2972 &   0.4746 ± 0.091 &         0.1 \\
# ABC   &  0.1237 ± 0.0641 &  0.1434 ± 0.1153 &  0.1421 ± 0.0786 &  0.1128 ± 0.0503 &         0.1 \\
# NL    &  0.1076 ± 0.0308 &  0.1214 ± 0.0737 &  0.1269 ± 0.0634 &  0.1101 ± 0.0419 &         0.1 \\
# Palma &  0.4201 ± 0.1159 &    0.9854 ± 0.02 &  0.8763 ± 0.0916 &  0.9425 ± 0.0205 &         1.0 \\
# Gini  &  0.4224 ± 0.1151 &  0.9944 ± 0.0028 &  0.8898 ± 0.1006 &  0.9427 ± 0.0203 &         1.0 \\
# Plain &  0.1227 ± 0.0274 &   0.933 ± 0.0246 &  0.6483 ± 0.2308 &   0.692 ± 0.0512 &         1.0 \\
# A     &  0.1368 ± 0.0658 &  0.9675 ± 0.0176 &  0.4849 ± 0.2694 &  0.6855 ± 0.1169 &         1.0 \\
# Npp   &  0.4419 ± 0.1131 &  0.4527 ± 0.1078 &   0.5839 ± 0.191 &  0.7059 ± 0.0544 &         1.0 \\
# Nre   &   0.1373 ± 0.066 &   0.973 ± 0.0134 &   0.495 ± 0.2928 &   0.7975 ± 0.047 &         1.0 \\
# ABC   &  0.1298 ± 0.0744 &  0.1441 ± 0.1197 &  0.1392 ± 0.0752 &  0.1128 ± 0.0503 &         1.0 \\
# NL    &  0.1078 ± 0.0313 &  0.1196 ± 0.0699 &  0.1268 ± 0.0632 &  0.1105 ± 0.0428 &         1.0 \\
# Palma &   0.6534 ± 0.133 &   0.923 ± 0.0599 &   0.851 ± 0.1007 &  0.9763 ± 0.0116 &        10.0 \\
# Gini  &  0.6615 ± 0.1325 &   0.9986 ± 0.001 &  0.9421 ± 0.0702 &    0.98 ± 0.0128 &        10.0 \\
# Plain &  0.4024 ± 0.1258 &  0.9809 ± 0.0066 &  0.8347 ± 0.1378 &  0.9023 ± 0.0284 &        10.0 \\
# A     &  0.2424 ± 0.1311 &  0.9358 ± 0.1257 &   0.485 ± 0.2583 &  0.7676 ± 0.1253 &        10.0 \\
# Npp   &   0.408 ± 0.0582 &   0.116 ± 0.0225 &    0.2688 ± 0.13 &  0.2549 ± 0.0583 &        10.0 \\
# Nre   &  0.2464 ± 0.1273 &  0.9647 ± 0.0555 &  0.5183 ± 0.2766 &   0.912 ± 0.0395 &        10.0 \\
# ABC   &  0.1183 ± 0.0575 &  0.1524 ± 0.1254 &   0.1471 ± 0.079 &  0.1128 ± 0.0503 &        10.0 \\
# NL    &  0.1077 ± 0.0309 &  0.1223 ± 0.0747 &  0.1267 ± 0.0632 &  0.1102 ± 0.0422 &        10.0 \\
# \bottomrule
# \end{tabular}
# <ipython-input-21-2096a7821416>:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(total_df.to_latex())

# %%
total_df.to_excel("SupplementaryTable2.xlsx")
