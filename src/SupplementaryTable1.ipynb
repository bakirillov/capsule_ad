# %%
import os
import re
import results
import numpy as np
import pandas as pd
import os.path as op
from sklearn.metrics import average_precision_score

# %%
fns = list(filter(lambda x: ".csv" in x, [a for a in os.walk("../models")][0][2]))

# %%
is_ABC = lambda x: "ABC" in x
is_NL = lambda x: "NL" in x
is_CN = lambda x: "CN" in x
is_SDI = lambda x: "SDI" in x
is_SDO = lambda x: "_SDO" in x
is_01 = lambda x: "_0.1_" in x
is_1 = lambda x: "_1_" in x
is_10 = lambda x: "_10_" in x
is_test = lambda x: "test" in x
is_train = lambda x: "train" in x
is_n = lambda x,n: "_"+str(n)+"_" in x
is_MNIST = lambda x: re.search("^MNIST", x)
is_FMNIST = lambda x: re.search("FMNIST", x)
is_KMNIST = lambda x: re.search("KMNIST", x)
is_CIFAR = lambda x: re.search("CIFAR", x)
is_HAM = lambda x: re.search("HAM", x)
is_PENG = lambda x: re.search("PENG", x)

# %%
fns = list(filter(is_test, fns))

# %%
total = {
    0.1: {
        "CIFAR": {
            "Palma": None,
            "Gini": None,
            "Plain": None,
            "A": None,
            "Npp": None,
            "Nre": None,
            "ABC": None,
            "NL": None,
        },
        "MNIST": {
            "Palma": None,
            "Gini": None,
            "Plain": None,
            "A": None,
            "Npp": None,
            "Nre": None,
            "ABC": None,
            "NL": None,
        },
        "FMNIST": {
            "Palma": None,
            "Gini": None,
            "Plain": None,
            "A": None,
            "Npp": None,
            "Nre": None,
            "ABC": None,
            "NL": None,
        },
        "KMNIST": {
            "Palma": None,
            "Gini": None,
            "Plain": None,
            "A": None,
            "Npp": None,
            "Nre": None,
            "ABC": None,
            "NL": None,
        }
    },
    1: {
        "CIFAR": {
            "Palma": None,
            "Gini": None,
            "Plain": None,
            "A": None,
            "Npp": None,
            "Nre": None,
            "ABC": None,
            "NL": None,
        },
        "MNIST": {
            "Palma": None,
            "Gini": None,
            "Plain": None,
            "A": None,
            "Npp": None,
            "Nre": None,
            "ABC": None,
            "NL": None,
        },
        "FMNIST": {
            "Palma": None,
            "Gini": None,
            "Plain": None,
            "A": None,
            "Npp": None,
            "Nre": None,
            "ABC": None,
            "NL": None,
        },
        "KMNIST": {
            "Palma": None,
            "Gini": None,
            "Plain": None,
            "A": None,
            "Npp": None,
            "Nre": None,
            "ABC": None,
            "NL": None,
        }    
    },
    10: {
        "CIFAR": {
            "Palma": None,
            "Gini": None,
            "Plain": None,
            "A": None,
            "Npp": None,
            "Nre": None,
            "ABC": None,
            "NL": None,
        },
        "MNIST": {
            "Palma": None,
            "Gini": None,
            "Plain": None,
            "A": None,
            "Npp": None,
            "Nre": None,
            "ABC": None,
            "NL": None,
        },
        "FMNIST": {
            "Palma": None,
            "Gini": None,
            "Plain": None,
            "A": None,
            "Npp": None,
            "Nre": None,
            "ABC": None,
            "NL": None,
        },
        "KMNIST": {
            "Palma": None,
            "Gini": None,
            "Plain": None,
            "A": None,
            "Npp": None,
            "Nre": None,
            "ABC": None,
            "NL": None,
        }
    }
}

# %% [markdown]
# # 0.1

# %%
CN = [op.join("../models", a) for a in 
     list(filter(lambda x: is_CN(x) and is_CIFAR(x) and is_01(x) and is_SDO(x), fns))]
ABC = [op.join("../models", a) for a in 
     list(filter(lambda x: is_ABC(x) and is_CIFAR(x) and is_01(x) and is_SDO(x), fns))]
NL = [op.join("../models", a) for a in 
     list(filter(lambda x: is_NL(x) and is_CIFAR(x) and is_01(x) and is_SDO(x), fns))]
CN_plain = [results.read_CN(a, "plain", average_precision_score) for a in CN]
CN_gini = [results.read_CN(a, "gini", average_precision_score) for a in CN]
CN_palma = [results.read_CN(a, "palma", average_precision_score) for a in CN]
CN_a = [results.read_CN(a, "anomaly_score", average_precision_score) for a in CN]
CN_npp = [results.read_CN(a, "n_pp", average_precision_score) for a in CN]
CN_nre = [results.read_CN(a, "n_re", average_precision_score) for a in CN]
ABC_ = [results.read_ABCNL(a, average_precision_score) for a in ABC]
NL_ = [results.read_ABCNL(a, average_precision_score) for a in NL]
column = [
    str(np.mean(a).round(4))+" ± "+str(np.std(a).round(4)) for a in [
        CN_palma, CN_gini, CN_plain, CN_a, CN_npp, CN_nre, ABC_, NL_
    ]
]
total[0.1]["CIFAR"]["Palma"] = column[0]
total[0.1]["CIFAR"]["Gini"] = column[1]
total[0.1]["CIFAR"]["Plain"] = column[2]
total[0.1]["CIFAR"]["A"] = column[3]
total[0.1]["CIFAR"]["Npp"] = column[4]
total[0.1]["CIFAR"]["Nre"] = column[5]
total[0.1]["CIFAR"]["ABC"] = column[6]
total[0.1]["CIFAR"]["NL"] = column[7]
print(len(CN), len(ABC), len(NL))
print(column)
# Out:
# 10 10 10
# ['0.9398 ± 0.0144', '0.94 ± 0.0144', '0.9 ± 0.0', '0.9227 ± 0.0247', '0.9408 ± 0.017', '0.9227 ± 0.0243', '0.9382 ± 0.0164', '0.9009 ± 0.0272']

# %%
CN = [op.join("../models", a) for a in 
     list(filter(lambda x: is_CN(x) and is_MNIST(x) and is_01(x) and is_SDO(x), fns))]
ABC = [op.join("../models", a) for a in 
     list(filter(lambda x: is_ABC(x) and is_MNIST(x) and is_01(x) and is_SDO(x), fns))]
NL = [op.join("../models", a) for a in 
     list(filter(lambda x: is_NL(x) and is_MNIST(x) and is_01(x) and is_SDO(x), fns))]
CN_plain = [results.read_CN(a, "plain", average_precision_score) for a in CN]
CN_gini = [results.read_CN(a, "gini", average_precision_score) for a in CN]
CN_palma = [results.read_CN(a, "palma", average_precision_score) for a in CN]
CN_a = [results.read_CN(a, "anomaly_score", average_precision_score) for a in CN]
CN_npp = [results.read_CN(a, "n_pp", average_precision_score) for a in CN]
CN_nre = [results.read_CN(a, "n_re", average_precision_score) for a in CN]
ABC_ = [results.read_ABCNL(a, average_precision_score) for a in ABC]
NL_ = [results.read_ABCNL(a, average_precision_score) for a in NL]
column = [
    str(np.mean(a).round(4))+" ± "+str(np.std(a).round(4)) for a in [
        CN_palma, CN_gini, CN_plain, CN_a, CN_npp, CN_nre, ABC_, NL_
    ]
]
total[0.1]["MNIST"]["Palma"] = column[0]
total[0.1]["MNIST"]["Gini"] = column[1]
total[0.1]["MNIST"]["Plain"] = column[2]
total[0.1]["MNIST"]["A"] = column[3]
total[0.1]["MNIST"]["Npp"] = column[4]
total[0.1]["MNIST"]["Nre"] = column[5]
total[0.1]["MNIST"]["ABC"] = column[6]
total[0.1]["MNIST"]["NL"] = column[7]
print(len(CN), len(ABC), len(NL))
print(column)
# Out:
# 10 10 10
# ['0.9794 ± 0.0121', '0.9791 ± 0.0123', '0.9157 ± 0.0118', '0.9898 ± 0.0072', '0.9896 ± 0.0081', '0.9948 ± 0.0032', '0.9724 ± 0.0163', '0.9022 ± 0.0456']

# %%
CN = [op.join("../models", a) for a in 
     list(filter(lambda x: is_CN(x) and is_KMNIST(x) and is_01(x) and is_SDO(x), fns))]
ABC = [op.join("../models", a) for a in 
     list(filter(lambda x: is_ABC(x) and is_KMNIST(x) and is_01(x) and is_SDO(x), fns))]
NL = [op.join("../models", a) for a in 
     list(filter(lambda x: is_NL(x) and is_KMNIST(x) and is_01(x) and is_SDO(x), fns))]
CN_plain = [results.read_CN(a, "plain", average_precision_score) for a in CN]
CN_gini = [results.read_CN(a, "gini", average_precision_score) for a in CN]
CN_palma = [results.read_CN(a, "palma", average_precision_score) for a in CN]
CN_a = [results.read_CN(a, "anomaly_score", average_precision_score) for a in CN]
CN_npp = [results.read_CN(a, "n_pp", average_precision_score) for a in CN]
CN_nre = [results.read_CN(a, "n_re", average_precision_score) for a in CN]
ABC_ = [results.read_ABCNL(a, average_precision_score) for a in ABC]
NL_ = [results.read_ABCNL(a, average_precision_score) for a in NL]
column = [
    str(np.mean(a).round(4))+" ± "+str(np.std(a).round(4)) for a in [
        CN_palma, CN_gini, CN_plain, CN_a, CN_npp, CN_nre, ABC_, NL_
    ]
]
total[0.1]["KMNIST"]["Palma"] = column[0]
total[0.1]["KMNIST"]["Gini"] = column[1]
total[0.1]["KMNIST"]["Plain"] = column[2]
total[0.1]["KMNIST"]["A"] = column[3]
total[0.1]["KMNIST"]["Npp"] = column[4]
total[0.1]["KMNIST"]["Nre"] = column[5]
total[0.1]["KMNIST"]["ABC"] = column[6]
total[0.1]["KMNIST"]["NL"] = column[7]
print(len(CN), len(ABC), len(NL))
print(column)
# Out:
# 10 10 10
# ['0.9637 ± 0.0095', '0.9634 ± 0.0097', '0.901 ± 0.002', '0.9606 ± 0.0151', '0.9777 ± 0.0079', '0.979 ± 0.0094', '0.9252 ± 0.0266', '0.9011 ± 0.0322']

# %%
CN = [op.join("../models", a) for a in 
     list(filter(lambda x: is_CN(x) and is_FMNIST(x) and is_01(x) and is_SDO(x), fns))]
ABC = [op.join("../models", a) for a in 
     list(filter(lambda x: is_ABC(x) and is_FMNIST(x) and is_01(x) and is_SDO(x), fns))]
NL = [op.join("../models", a) for a in 
     list(filter(lambda x: is_NL(x) and is_FMNIST(x) and is_01(x) and is_SDO(x), fns))]
CN_plain = [results.read_CN(a, "plain", average_precision_score) for a in CN]
CN_gini = [results.read_CN(a, "gini", average_precision_score) for a in CN]
CN_palma = [results.read_CN(a, "palma", average_precision_score) for a in CN]
CN_a = [results.read_CN(a, "anomaly_score", average_precision_score) for a in CN]
CN_npp = [results.read_CN(a, "n_pp", average_precision_score) for a in CN]
CN_nre = [results.read_CN(a, "n_re", average_precision_score) for a in CN]
ABC_ = [results.read_ABCNL(a, average_precision_score) for a in ABC]
NL_ = [results.read_ABCNL(a, average_precision_score) for a in NL]
column = [
    str(np.mean(a).round(4))+" ± "+str(np.std(a).round(4)) for a in [
        CN_palma, CN_gini, CN_plain, CN_a, CN_npp, CN_nre, ABC_, NL_
    ]
]
total[0.1]["FMNIST"]["Palma"] = column[0]
total[0.1]["FMNIST"]["Gini"] = column[1]
total[0.1]["FMNIST"]["Plain"] = column[2]
total[0.1]["FMNIST"]["A"] = column[3]
total[0.1]["FMNIST"]["Npp"] = column[4]
total[0.1]["FMNIST"]["Nre"] = column[5]
total[0.1]["FMNIST"]["ABC"] = column[6]
total[0.1]["FMNIST"]["NL"] = column[7]
print(len(CN), len(ABC), len(NL))
print(column)
# Out:
# 10 10 10
# ['0.9795 ± 0.0165', '0.98 ± 0.0163', '0.9152 ± 0.0234', '0.9857 ± 0.0087', '0.9855 ± 0.0074', '0.9881 ± 0.0117', '0.9615 ± 0.035', '0.903 ± 0.0577']

# %% [markdown]
# # 1

# %%
selfun = lambda x: is_CIFAR(x) and is_1(x) and is_SDO(x) and not is_10(x) and not is_01(x)
CN = [op.join("../models", a) for a in 
     list(
         filter(lambda x: is_CN(x) and selfun(x), fns)
     )]
ABC = [op.join("../models", a) for a in 
     list(filter(lambda x: is_ABC(x) and selfun(x), fns))]
NL = [op.join("../models", a) for a in 
     list(filter(lambda x: is_NL(x) and selfun(x), fns))]
CN_plain = [results.read_CN(a, "plain", average_precision_score) for a in CN]
CN_gini = [results.read_CN(a, "gini", average_precision_score) for a in CN]
CN_palma = [results.read_CN(a, "palma", average_precision_score) for a in CN]
CN_a = [results.read_CN(a, "anomaly_score", average_precision_score) for a in CN]
CN_npp = [results.read_CN(a, "n_pp", average_precision_score) for a in CN]
CN_nre = [results.read_CN(a, "n_re", average_precision_score) for a in CN]
ABC_ = [results.read_ABCNL(a, average_precision_score) for a in ABC]
NL_ = [results.read_ABCNL(a, average_precision_score) for a in NL]
column = [
    str(np.mean(a).round(4))+" ± "+str(np.std(a).round(4)) for a in [
        CN_palma, CN_gini, CN_plain, CN_a, CN_npp, CN_nre, ABC_, NL_
    ]
]
total[1]["CIFAR"]["Palma"] = column[0]
total[1]["CIFAR"]["Gini"] = column[1]
total[1]["CIFAR"]["Plain"] = column[2]
total[1]["CIFAR"]["A"] = column[3]
total[1]["CIFAR"]["Npp"] = column[4]
total[1]["CIFAR"]["Nre"] = column[5]
total[1]["CIFAR"]["ABC"] = column[6]
total[1]["CIFAR"]["NL"] = column[7]
print(len(CN), len(ABC), len(NL))
print(column)
# Out:
# 10 10 10
# ['0.9573 ± 0.013', '0.9573 ± 0.013', '0.9001 ± 0.0002', '0.923 ± 0.0267', '0.9598 ± 0.0128', '0.9231 ± 0.0274', '0.9381 ± 0.0188', '0.9008 ± 0.0272']

# %%
selfun = lambda x: is_MNIST(x) and is_1(x) and is_SDO(x) and not is_10(x) and not is_01(x)
CN = [op.join("../models", a) for a in 
     list(filter(lambda x: is_CN(x) and selfun(x), fns))]
ABC = [op.join("../models", a) for a in 
     list(filter(lambda x: is_ABC(x) and selfun(x), fns))]
NL = [op.join("../models", a) for a in 
     list(filter(lambda x: is_NL(x) and selfun(x), fns))]
CN_plain = [results.read_CN(a, "plain", average_precision_score) for a in CN]
CN_gini = [results.read_CN(a, "gini", average_precision_score) for a in CN]
CN_palma = [results.read_CN(a, "palma", average_precision_score) for a in CN]
CN_a = [results.read_CN(a, "anomaly_score", average_precision_score) for a in CN]
CN_npp = [results.read_CN(a, "n_pp", average_precision_score) for a in CN]
CN_nre = [results.read_CN(a, "n_re", average_precision_score) for a in CN]
ABC_ = [results.read_ABCNL(a, average_precision_score) for a in ABC]
NL_ = [results.read_ABCNL(a, average_precision_score) for a in NL]
column = [
    str(np.mean(a).round(4))+" ± "+str(np.std(a).round(4)) for a in [
        CN_palma, CN_gini, CN_plain, CN_a, CN_npp, CN_nre, ABC_, NL_
    ]
]
total[1]["MNIST"]["Palma"] = column[0]
total[1]["MNIST"]["Gini"] = column[1]
total[1]["MNIST"]["Plain"] = column[2]
total[1]["MNIST"]["A"] = column[3]
total[1]["MNIST"]["Npp"] = column[4]
total[1]["MNIST"]["Nre"] = column[5]
total[1]["MNIST"]["ABC"] = column[6]
total[1]["MNIST"]["NL"] = column[7]
print(len(CN), len(ABC), len(NL))
print(column)
# Out:
# 10 10 10
# ['0.9978 ± 0.0013', '0.998 ± 0.0014', '0.9728 ± 0.0116', '0.9939 ± 0.0043', '0.9942 ± 0.0037', '0.9976 ± 0.0017', '0.9725 ± 0.016', '0.9027 ± 0.0455']

# %%
selfun = lambda x: is_KMNIST(x) and is_1(x) and is_SDO(x) and not is_10(x) and not is_01(x)
CN = [op.join("../models", a) for a in 
     list(filter(lambda x: is_CN(x) and selfun(x), fns))]
ABC = [op.join("../models", a) for a in 
     list(filter(lambda x: is_ABC(x) and selfun(x), fns))]
NL = [op.join("../models", a) for a in 
     list(filter(lambda x: is_NL(x) and selfun(x), fns))]
CN_plain = [results.read_CN(a, "plain", average_precision_score) for a in CN]
CN_gini = [results.read_CN(a, "gini", average_precision_score) for a in CN]
CN_palma = [results.read_CN(a, "palma", average_precision_score) for a in CN]
CN_a = [results.read_CN(a, "anomaly_score", average_precision_score) for a in CN]
CN_npp = [results.read_CN(a, "n_pp", average_precision_score) for a in CN]
CN_nre = [results.read_CN(a, "n_re", average_precision_score) for a in CN]
ABC_ = [results.read_ABCNL(a, average_precision_score) for a in ABC]
NL_ = [results.read_ABCNL(a, average_precision_score) for a in NL]
column = [
    str(np.mean(a).round(4))+" ± "+str(np.std(a).round(4)) for a in [
        CN_palma, CN_gini, CN_plain, CN_a, CN_npp, CN_nre, ABC_, NL_
    ]
]
total[1]["KMNIST"]["Palma"] = column[0]
total[1]["KMNIST"]["Gini"] = column[1]
total[1]["KMNIST"]["Plain"] = column[2]
total[1]["KMNIST"]["A"] = column[3]
total[1]["KMNIST"]["Npp"] = column[4]
total[1]["KMNIST"]["Nre"] = column[5]
total[1]["KMNIST"]["ABC"] = column[6]
total[1]["KMNIST"]["NL"] = column[7]
print(len(CN), len(ABC), len(NL))
print(column)
# Out:
# 10 10 10
# ['0.9889 ± 0.0043', '0.9887 ± 0.0043', '0.9328 ± 0.0138', '0.966 ± 0.0102', '0.9907 ± 0.0036', '0.9838 ± 0.0077', '0.9256 ± 0.0267', '0.9011 ± 0.0318']

# %%
selfun = lambda x: is_FMNIST(x) and is_1(x) and is_SDO(x) and not is_10(x) and not is_01(x)
CN = [op.join("../models", a) for a in 
     list(filter(lambda x: is_CN(x) and selfun(x), fns))]
ABC = [op.join("../models", a) for a in 
     list(filter(lambda x: is_ABC(x) and selfun(x), fns))]
NL = [op.join("../models", a) for a in 
     list(filter(lambda x: is_NL(x) and selfun(x), fns))]
CN_plain = [results.read_CN(a, "plain", average_precision_score) for a in CN]
CN_gini = [results.read_CN(a, "gini", average_precision_score) for a in CN]
CN_palma = [results.read_CN(a, "palma", average_precision_score) for a in CN]
CN_a = [results.read_CN(a, "anomaly_score", average_precision_score) for a in CN]
CN_npp = [results.read_CN(a, "n_pp", average_precision_score) for a in CN]
CN_nre = [results.read_CN(a, "n_re", average_precision_score) for a in CN]
ABC_ = [results.read_ABCNL(a, average_precision_score) for a in ABC]
NL_ = [results.read_ABCNL(a, average_precision_score) for a in NL]
column = [
    str(np.mean(a).round(4))+" ± "+str(np.std(a).round(4)) for a in [
        CN_palma, CN_gini, CN_plain, CN_a, CN_npp, CN_nre, ABC_, NL_
    ]
]
total[1]["FMNIST"]["Palma"] = column[0]
total[1]["FMNIST"]["Gini"] = column[1]
total[1]["FMNIST"]["Plain"] = column[2]
total[1]["FMNIST"]["A"] = column[3]
total[1]["FMNIST"]["Npp"] = column[4]
total[1]["FMNIST"]["Nre"] = column[5]
total[1]["FMNIST"]["ABC"] = column[6]
total[1]["FMNIST"]["NL"] = column[7]
print(len(CN), len(ABC), len(NL))
print(column)
# Out:
# 10 10 10
# ['0.9931 ± 0.0055', '0.9931 ± 0.0055', '0.9605 ± 0.0159', '0.9884 ± 0.0084', '0.9855 ± 0.0103', '0.9887 ± 0.0124', '0.9616 ± 0.0347', '0.903 ± 0.0578']

# %% [markdown]
# # 10

# %%
CN = [op.join("../models", a) for a in 
     list(filter(lambda x: is_CN(x) and is_CIFAR(x) and is_10(x) and is_SDO(x), fns))]
ABC = [op.join("../models", a) for a in 
     list(filter(lambda x: is_ABC(x) and is_CIFAR(x) and is_10(x) and is_SDO(x), fns))]
NL = [op.join("../models", a) for a in 
     list(filter(lambda x: is_NL(x) and is_CIFAR(x) and is_10(x) and is_SDO(x), fns))]
CN_plain = [results.read_CN(a, "plain", average_precision_score) for a in CN]
CN_gini = [results.read_CN(a, "gini", average_precision_score) for a in CN]
CN_palma = [results.read_CN(a, "palma", average_precision_score) for a in CN]
CN_a = [results.read_CN(a, "anomaly_score", average_precision_score) for a in CN]
CN_npp = [results.read_CN(a, "n_pp", average_precision_score) for a in CN]
CN_nre = [results.read_CN(a, "n_re", average_precision_score) for a in CN]
ABC_ = [results.read_ABCNL(a, average_precision_score) for a in ABC]
NL_ = [results.read_ABCNL(a, average_precision_score) for a in NL]
column = [
    str(np.mean(a).round(4))+" ± "+str(np.std(a).round(4)) for a in [
        CN_palma, CN_gini, CN_plain, CN_a, CN_npp, CN_nre, ABC_, NL_
    ]
]
total[10]["CIFAR"]["Palma"] = column[0]
total[10]["CIFAR"]["Gini"] = column[1]
total[10]["CIFAR"]["Plain"] = column[2]
total[10]["CIFAR"]["A"] = column[3]
total[10]["CIFAR"]["Npp"] = column[4]
total[10]["CIFAR"]["Nre"] = column[5]
total[10]["CIFAR"]["ABC"] = column[6]
total[10]["CIFAR"]["NL"] = column[7]
print(len(CN), len(ABC), len(NL))
print(column)
# Out:
# 10 10 10
# ['0.9766 ± 0.0073', '0.9768 ± 0.0073', '0.9273 ± 0.0127', '0.933 ± 0.0189', '0.9681 ± 0.0092', '0.9342 ± 0.0187', '0.94 ± 0.0167', '0.9009 ± 0.0272']

# %%
CN = [op.join("../models", a) for a in 
     list(filter(lambda x: is_CN(x) and is_MNIST(x) and is_10(x) and is_SDO(x), fns))]
ABC = [op.join("../models", a) for a in 
     list(filter(lambda x: is_ABC(x) and is_MNIST(x) and is_10(x) and is_SDO(x), fns))]
NL = [op.join("../models", a) for a in 
     list(filter(lambda x: is_NL(x) and is_MNIST(x) and is_10(x) and is_SDO(x), fns))]
CN_plain = [results.read_CN(a, "plain", average_precision_score) for a in CN]
CN_gini = [results.read_CN(a, "gini", average_precision_score) for a in CN]
CN_palma = [results.read_CN(a, "palma", average_precision_score) for a in CN]
CN_a = [results.read_CN(a, "anomaly_score", average_precision_score) for a in CN]
CN_npp = [results.read_CN(a, "n_pp", average_precision_score) for a in CN]
CN_nre = [results.read_CN(a, "n_re", average_precision_score) for a in CN]
ABC_ = [results.read_ABCNL(a, average_precision_score) for a in ABC]
NL_ = [results.read_ABCNL(a, average_precision_score) for a in NL]
column = [
    str(np.mean(a).round(4))+" ± "+str(np.std(a).round(4)) for a in [
        CN_palma, CN_gini, CN_plain, CN_a, CN_npp, CN_nre, ABC_, NL_
    ]
]
total[10]["MNIST"]["Palma"] = column[0]
total[10]["MNIST"]["Gini"] = column[1]
total[10]["MNIST"]["Plain"] = column[2]
total[10]["MNIST"]["A"] = column[3]
total[10]["MNIST"]["Npp"] = column[4]
total[10]["MNIST"]["Nre"] = column[5]
total[10]["MNIST"]["ABC"] = column[6]
total[10]["MNIST"]["NL"] = column[7]
print(len(CN), len(ABC), len(NL))
print(column)
# Out:
# 10 10 10
# ['0.9978 ± 0.0024', '0.9998 ± 0.0001', '0.9964 ± 0.0012', '0.9943 ± 0.0049', '0.962 ± 0.0137', '0.9987 ± 0.0011', '0.9744 ± 0.0163', '0.9023 ± 0.0454']

# %%
CN = [op.join("../models", a) for a in 
     list(filter(lambda x: is_CN(x) and is_KMNIST(x) and is_10(x) and is_SDO(x), fns))]
ABC = [op.join("../models", a) for a in 
     list(filter(lambda x: is_ABC(x) and is_KMNIST(x) and is_10(x) and is_SDO(x), fns))]
NL = [op.join("../models", a) for a in 
     list(filter(lambda x: is_NL(x) and is_KMNIST(x) and is_10(x) and is_SDO(x), fns))]
CN_plain = [results.read_CN(a, "plain", average_precision_score) for a in CN]
CN_gini = [results.read_CN(a, "gini", average_precision_score) for a in CN]
CN_palma = [results.read_CN(a, "palma", average_precision_score) for a in CN]
CN_a = [results.read_CN(a, "anomaly_score", average_precision_score) for a in CN]
CN_npp = [results.read_CN(a, "n_pp", average_precision_score) for a in CN]
CN_nre = [results.read_CN(a, "n_re", average_precision_score) for a in CN]
ABC_ = [results.read_ABCNL(a, average_precision_score) for a in ABC]
NL_ = [results.read_ABCNL(a, average_precision_score) for a in NL]
column = [
    str(np.mean(a).round(4))+" ± "+str(np.std(a).round(4)) for a in [
        CN_palma, CN_gini, CN_plain, CN_a, CN_npp, CN_nre, ABC_, NL_
    ]
]
total[10]["KMNIST"]["Palma"] = column[0]
total[10]["KMNIST"]["Gini"] = column[1]
total[10]["KMNIST"]["Plain"] = column[2]
total[10]["KMNIST"]["A"] = column[3]
total[10]["KMNIST"]["Npp"] = column[4]
total[10]["KMNIST"]["Nre"] = column[5]
total[10]["KMNIST"]["ABC"] = column[6]
total[10]["KMNIST"]["NL"] = column[7]
print(len(CN), len(ABC), len(NL))
print(column)
# Out:
# 10 10 10
# ['0.9958 ± 0.0031', '0.9967 ± 0.0024', '0.9811 ± 0.0073', '0.967 ± 0.0122', '0.9643 ± 0.0108', '0.9861 ± 0.0061', '0.9284 ± 0.0287', '0.9012 ± 0.0322']

# %%
CN = [op.join("../models", a) for a in 
     list(filter(lambda x: is_CN(x) and is_FMNIST(x) and is_10(x) and is_SDO(x), fns))]
ABC = [op.join("../models", a) for a in 
     list(filter(lambda x: is_ABC(x) and is_FMNIST(x) and is_10(x) and is_SDO(x), fns))]
NL = [op.join("../models", a) for a in 
     list(filter(lambda x: is_NL(x) and is_FMNIST(x) and is_10(x) and is_SDO(x), fns))]
CN_plain = [results.read_CN(a, "plain", average_precision_score) for a in CN]
CN_gini = [results.read_CN(a, "gini", average_precision_score) for a in CN]
CN_palma = [results.read_CN(a, "palma", average_precision_score) for a in CN]
CN_a = [results.read_CN(a, "anomaly_score", average_precision_score) for a in CN]
CN_npp = [results.read_CN(a, "n_pp", average_precision_score) for a in CN]
CN_nre = [results.read_CN(a, "n_re", average_precision_score) for a in CN]
ABC_ = [results.read_ABCNL(a, average_precision_score) for a in ABC]
NL_ = [results.read_ABCNL(a, average_precision_score) for a in NL]
column = [
    str(np.mean(a).round(4))+" ± "+str(np.std(a).round(4)) for a in [
        CN_palma, CN_gini, CN_plain, CN_a, CN_npp, CN_nre, ABC_, NL_
    ]
]
total[10]["FMNIST"]["Palma"] = column[0]
total[10]["FMNIST"]["Gini"] = column[1]
total[10]["FMNIST"]["Plain"] = column[2]
total[10]["FMNIST"]["A"] = column[3]
total[10]["FMNIST"]["Npp"] = column[4]
total[10]["FMNIST"]["Nre"] = column[5]
total[10]["FMNIST"]["ABC"] = column[6]
total[10]["FMNIST"]["NL"] = column[7]
print(len(CN), len(ABC), len(NL))
print(column)
# Out:
# 10 10 10
# ['0.9955 ± 0.0041', '0.9975 ± 0.0032', '0.9841 ± 0.0111', '0.987 ± 0.0143', '0.9586 ± 0.0164', '0.9856 ± 0.0176', '0.9618 ± 0.0353', '0.903 ± 0.0576']

# %% [markdown]
# # Results

# %%
first = pd.DataFrame(total[0.1])
first["Proportion"] = 0.1
second = pd.DataFrame(total[1])
second["Proportion"] = 1
third = pd.DataFrame(total[10])
third["Proportion"] = 10

# %%
total_df = pd.concat([first, second, third])

# %%
total_df
# Out:
#                  CIFAR            MNIST           FMNIST           KMNIST  \
# Palma  0.9398 ± 0.0144  0.9794 ± 0.0121  0.9795 ± 0.0165  0.9637 ± 0.0095
# Gini     0.94 ± 0.0144  0.9791 ± 0.0123    0.98 ± 0.0163  0.9634 ± 0.0097
# Plain        0.9 ± 0.0  0.9157 ± 0.0118  0.9152 ± 0.0234    0.901 ± 0.002
# A      0.9227 ± 0.0247  0.9898 ± 0.0072  0.9857 ± 0.0087  0.9606 ± 0.0151
# Npp     0.9408 ± 0.017  0.9896 ± 0.0081  0.9855 ± 0.0074  0.9777 ± 0.0079
# Nre    0.9227 ± 0.0243  0.9948 ± 0.0032  0.9881 ± 0.0117   0.979 ± 0.0094
# ABC    0.9382 ± 0.0164  0.9724 ± 0.0163   0.9615 ± 0.035  0.9252 ± 0.0266
# NL     0.9009 ± 0.0272  0.9022 ± 0.0456   0.903 ± 0.0577  0.9011 ± 0.0322
# Palma   0.9573 ± 0.013  0.9978 ± 0.0013  0.9931 ± 0.0055  0.9889 ± 0.0043
# Gini    0.9573 ± 0.013   0.998 ± 0.0014  0.9931 ± 0.0055  0.9887 ± 0.0043
# Plain  0.9001 ± 0.0002  0.9728 ± 0.0116  0.9605 ± 0.0159  0.9328 ± 0.0138
# A       0.923 ± 0.0267  0.9939 ± 0.0043  0.9884 ± 0.0084   0.966 ± 0.0102
# Npp    0.9598 ± 0.0128  0.9942 ± 0.0037  0.9855 ± 0.0103  0.9907 ± 0.0036
# Nre    0.9231 ± 0.0274  0.9976 ± 0.0017  0.9887 ± 0.0124  0.9838 ± 0.0077
# ABC    0.9381 ± 0.0188   0.9725 ± 0.016  0.9616 ± 0.0347  0.9256 ± 0.0267
# NL     0.9008 ± 0.0272  0.9027 ± 0.0455   0.903 ± 0.0578  0.9011 ± 0.0318
# Palma  0.9766 ± 0.0073  0.9978 ± 0.0024  0.9955 ± 0.0041  0.9958 ± 0.0031
# Gini   0.9768 ± 0.0073  0.9998 ± 0.0001  0.9975 ± 0.0032  0.9967 ± 0.0024
# Plain  0.9273 ± 0.0127  0.9964 ± 0.0012  0.9841 ± 0.0111  0.9811 ± 0.0073
# A       0.933 ± 0.0189  0.9943 ± 0.0049   0.987 ± 0.0143   0.967 ± 0.0122
# Npp    0.9681 ± 0.0092   0.962 ± 0.0137  0.9586 ± 0.0164  0.9643 ± 0.0108
# Nre    0.9342 ± 0.0187  0.9987 ± 0.0011  0.9856 ± 0.0176  0.9861 ± 0.0061
# ABC      0.94 ± 0.0167  0.9744 ± 0.0163  0.9618 ± 0.0353  0.9284 ± 0.0287
# NL     0.9009 ± 0.0272  0.9023 ± 0.0454   0.903 ± 0.0576  0.9012 ± 0.0322
#
#        Proportion
# Palma         0.1
# Gini          0.1
# Plain         0.1
# A             0.1
# Npp           0.1
# Nre           0.1
# ABC           0.1
# NL            0.1
# Palma         1.0
# Gini          1.0
# Plain         1.0
# A             1.0
# Npp           1.0
# Nre           1.0
# ABC           1.0
# NL            1.0
# Palma        10.0
# Gini         10.0
# Plain        10.0
# A            10.0
# Npp          10.0
# Nre          10.0
# ABC          10.0
# NL           10.0

# %%
print(total_df.to_latex())
# Out:
# \begin{tabular}{lllllr}
# \toprule
# {} &            CIFAR &            MNIST &           FMNIST &           KMNIST &  Proportion \\
# \midrule
# Palma &  0.9398 ± 0.0144 &  0.9794 ± 0.0121 &  0.9795 ± 0.0165 &  0.9637 ± 0.0095 &         0.1 \\
# Gini  &    0.94 ± 0.0144 &  0.9791 ± 0.0123 &    0.98 ± 0.0163 &  0.9634 ± 0.0097 &         0.1 \\
# Plain &        0.9 ± 0.0 &  0.9157 ± 0.0118 &  0.9152 ± 0.0234 &    0.901 ± 0.002 &         0.1 \\
# A     &  0.9227 ± 0.0247 &  0.9898 ± 0.0072 &  0.9857 ± 0.0087 &  0.9606 ± 0.0151 &         0.1 \\
# Npp   &   0.9408 ± 0.017 &  0.9896 ± 0.0081 &  0.9855 ± 0.0074 &  0.9777 ± 0.0079 &         0.1 \\
# Nre   &  0.9227 ± 0.0243 &  0.9948 ± 0.0032 &  0.9881 ± 0.0117 &   0.979 ± 0.0094 &         0.1 \\
# ABC   &  0.9382 ± 0.0164 &  0.9724 ± 0.0163 &   0.9615 ± 0.035 &  0.9252 ± 0.0266 &         0.1 \\
# NL    &  0.9009 ± 0.0272 &  0.9022 ± 0.0456 &   0.903 ± 0.0577 &  0.9011 ± 0.0322 &         0.1 \\
# Palma &   0.9573 ± 0.013 &  0.9978 ± 0.0013 &  0.9931 ± 0.0055 &  0.9889 ± 0.0043 &         1.0 \\
# Gini  &   0.9573 ± 0.013 &   0.998 ± 0.0014 &  0.9931 ± 0.0055 &  0.9887 ± 0.0043 &         1.0 \\
# Plain &  0.9001 ± 0.0002 &  0.9728 ± 0.0116 &  0.9605 ± 0.0159 &  0.9328 ± 0.0138 &         1.0 \\
# A     &   0.923 ± 0.0267 &  0.9939 ± 0.0043 &  0.9884 ± 0.0084 &   0.966 ± 0.0102 &         1.0 \\
# Npp   &  0.9598 ± 0.0128 &  0.9942 ± 0.0037 &  0.9855 ± 0.0103 &  0.9907 ± 0.0036 &         1.0 \\
# Nre   &  0.9231 ± 0.0274 &  0.9976 ± 0.0017 &  0.9887 ± 0.0124 &  0.9838 ± 0.0077 &         1.0 \\
# ABC   &  0.9381 ± 0.0188 &   0.9725 ± 0.016 &  0.9616 ± 0.0347 &  0.9256 ± 0.0267 &         1.0 \\
# NL    &  0.9008 ± 0.0272 &  0.9027 ± 0.0455 &   0.903 ± 0.0578 &  0.9011 ± 0.0318 &         1.0 \\
# Palma &  0.9766 ± 0.0073 &  0.9978 ± 0.0024 &  0.9955 ± 0.0041 &  0.9958 ± 0.0031 &        10.0 \\
# Gini  &  0.9768 ± 0.0073 &  0.9998 ± 0.0001 &  0.9975 ± 0.0032 &  0.9967 ± 0.0024 &        10.0 \\
# Plain &  0.9273 ± 0.0127 &  0.9964 ± 0.0012 &  0.9841 ± 0.0111 &  0.9811 ± 0.0073 &        10.0 \\
# A     &   0.933 ± 0.0189 &  0.9943 ± 0.0049 &   0.987 ± 0.0143 &   0.967 ± 0.0122 &        10.0 \\
# Npp   &  0.9681 ± 0.0092 &   0.962 ± 0.0137 &  0.9586 ± 0.0164 &  0.9643 ± 0.0108 &        10.0 \\
# Nre   &  0.9342 ± 0.0187 &  0.9987 ± 0.0011 &  0.9856 ± 0.0176 &  0.9861 ± 0.0061 &        10.0 \\
# ABC   &    0.94 ± 0.0167 &  0.9744 ± 0.0163 &  0.9618 ± 0.0353 &  0.9284 ± 0.0287 &        10.0 \\
# NL    &  0.9009 ± 0.0272 &  0.9023 ± 0.0454 &   0.903 ± 0.0576 &  0.9012 ± 0.0322 &        10.0 \\
# \bottomrule
# \end{tabular}
# <ipython-input-22-2096a7821416>:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(total_df.to_latex())

# %%
total_df.to_excel("SupplementaryTable1.xlsx")
